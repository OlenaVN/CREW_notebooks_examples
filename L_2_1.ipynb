# %% [markdown]
# <a href="https://colab.research.google.com/github/OlenaVN/CREW_notebooks_examples/blob/main/L_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# **Project Plan for Website Development for a Small Business**
#
# ---
#
# **1. Project Overview**
#
# Goal: Create a modern, responsive website for a small business that effectively showcases its services and enhances customer engagement.
#
# **Project Team:**
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# ---
#
# **2. Task Breakdown with Timelines and Dependencies**
#
# | Task ID | Task Description                                                                                              | Scope                                                                                                          | Assigned To         | Duration | Start Date  | End Date    | Dependencies                                  | Deliverables                               |
# |---------|---------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------|---------------------|----------|-------------|-------------|----------------------------------------------|--------------------------------------------|
# | 1       | Create responsive design                                                                                     | Develop a design layout adaptable to desktop and mobile platforms. Design wireframes for review.               | Bob Smith           | 5 days   | 10/01/2023  | 10/05/2023  | None                                         | Wireframes & Design Mockups                |
# | 2       | Implement modern User Interface (UI)                                                                          | Design a visually appealing UI with a clean look and feel based on the approved wireframes.                    | Jane Doe            | 7 days   | 10/06/2023  | 10/12/2023  | Task 1                                       | UI Prototype                                |
# | 3       | Develop user-friendly navigation system                                                                       | Create an intuitive menu structure to enhance usability and accessibility on different devices.                 | Jane Doe            | 3 days   | 10/13/2023  | 10/15/2023  | Task 2                                       | Navigation Menu Implementation              |
# | 4       | Create "About Us" page                                                                                      | Write and design content to convey the company’s history, mission, and values.                                  | Bob Smith           | 2 days   | 10/16/2023  | 10/17/2023  | Task 2                                       | Completed "About Us" Page                  |
# | 5       | Design "Services" page                                                                                      | Showcase the business offerings with engaging visuals and detailed descriptions.                                 | Bob Smith           | 3 days   | 10/18/2023  | 10/20/2023  | Task 2                                       | Completed "Services" Page                  |
# | 6       | Create "Contact Us" page                                                                                   | Design a contact form and integrate a map for customer interaction and location accessibility.                  | Bob Smith           | 3 days   | 10/21/2023  | 10/23/2023  | Task 2                                       | Completed "Contact Us" Page                |
# | 7       | Implement blog section                                                                                     | Develop a blog feature for sharing industry news and company updates; include a CMS for content management.     | Jane Doe            | 5 days   | 10/24/2023  | 10/28/2023  | Task 2                                       | Blog Feature Implementation                 |
# | 8       | Ensure fast loading times and SEO optimization                                                               | Optimize website performance and apply SEO strategies (keywords, meta tags, etc.) for better visibility.        | Jane Doe            | 4 days   | 10/29/2023  | 11/01/2023  | Task 2                                       | Performance and SEO Audit                   |
# | 9       | Integrate social media links and sharing capabilities                                                        | Add social media buttons and links throughout the website for enhanced engagement and connectivity.              | Jane Doe            | 2 days   | 11/02/2023  | 11/03/2023  | Task 2                                       | Social Media Integration                    |
# | 10      | Create testimonials section                                                                                  | Gather and format customer testimonials to display on the website, enhancing credibility.                        | Bob Smith           | 2 days   | 11/04/2023  | 11/05/2023  | Task 2                                       | Completed Testimonials Section              |
# | 11      | Quality Assurance Testing                                                                                   | Conduct thorough testing of all website functionalities and sections to ensure quality and performance.        | Alice Johnson, Tom Brown | 4 days   | 11/06/2023  | 11/09/2023  | Tasks 3-10                                   | QA Testing Report                           |
# | 12      | Review and Final Adjustments                                                                                 | Address any feedback from QA testing and make final adjustments before launch.                                  | Jane Doe            | 3 days   | 11/10/2023  | 11/12/2023  | Task 11                                      | Final Website                                  |
# | 13      | Launch Website                                                                                               | Deploy the website to the live server and ensure everything is functioning as expected.                        | Jane Doe            | 1 day    | 11/13/2023  | 11/13/2023  | Task 12                                      | Live Website                                |
#
# ---
#
# **3. Gantt Chart Timeline Visualization**
#
# ```
# | Task ID | Task Description             | 10/01 | 10/06 | 10/13 | 10/16 | 10/18 | 10/21 | 10/24 | 10/29 | 11/02 | 11/04 | 11/06 | 11/10 | 11/13 |
# |---------|------------------------------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|--------|
# | 1       | Create responsive design     |   XXX  |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |
# | 2       | Implement modern UI          |   -    |   XXX  |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |
# | 3       | Develop navigation system     |   -    |   -    |   XXX  |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |
# | 4       | Create "About Us" page      |   -    |   -    |   -    |   XXX  |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |
# | 5       | Design "Services" page      |   -    |   -    |   -    |   -    |   XXX  |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |
# | 6       | Create "Contact Us" page    |   -    |   -    |   -    |   -    |   -    |   XXX  |   -    |   -    |   -    |   -    |   -    |   -    |   -    |
# | 7       | Implement blog section       |   -    |   -    |   -    |   -    |   -    |   -    |   XXX  |   -    |   -    |   -    |   -    |   -    |   -    |
# | 8       | Ensure performance and SEO   |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   XXX  |   -    |   -    |   -    |   -    |   -    |
# | 9       | Social media integration     |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   XXX  |   -    |   -    |   -    |   -    |
# | 10      | Create testimonials section   |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   XXX  |   -    |   -    |   -    |
# | 11      | Quality Assurance Testing     |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   XXX  |   -    |   -    |
# | 12      | Review and Final Adjustments |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   XXX  |   -    |
# | 13      | Launch Website               |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   -    |   XXX  |
# ```
#
# ---
#
# **4. Conclusion**
#
# This comprehensive plan details each actionable task required to create a high-quality website for a small business, ensuring careful attention to all aspects of design, functionality, and user experience. With designated timelines and a marked workflow, team members will have clarity on their responsibilities, and the project will be positioned for successful completion by the target launch date.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# **Estimation Report for Website Project**
#
# ---
#
# **1. Project Overview Summary**
#
# The goal of this project is to create a modern, responsive website for a small business, enhancing customer engagement and effectively showcasing its services. The project team consists of John Doe (Project Manager), Jane Doe (Software Engineer), Bob Smith (Designer), Alice Johnson (QA Engineer), and Tom Brown (QA Engineer).
#
# ---
#
# **2. Detailed Task Estimation**
#
# | Task ID | Task Description                              | Estimated Time (Days) | Resources Required              | Effort Level | Risks/Uncertainties                                    | Deliverables                               |
# |---------|-----------------------------------------------|-----------------------|----------------------------------|--------------|--------------------------------------------------------|--------------------------------------------|
# | 1       | Create responsive design                      | 5                     | 1 Designer                       | Medium       | Complexity in compatibility across devices              | Wireframes & Design Mockups                |
# | 2       | Implement modern User Interface (UI)         | 7                     | 1 Software Engineer, 1 Designer | High         | Design iterations may delay progress                     | UI Prototype                                |
# | 3       | Develop user-friendly navigation system       | 3                     | 1 Software Engineer              | Low          | User feedback may necessitate adjustments               | Navigation Menu Implementation              |
# | 4       | Create "About Us" page                       | 2                     | 1 Designer                       | Low          | Content approval delays could affect timeline           | Completed "About Us" Page                  |
# | 5       | Design "Services" page                       | 3                     | 1 Designer                       | Medium       | Need for client input on services offered               | Completed "Services" Page                  |
# | 6       | Create "Contact Us" page                     | 3                     | 1 Designer                       | Medium       | Integration with existing systems may cause delays      | Completed "Contact Us" Page                |
# | 7       | Implement blog section                        | 5                     | 1 Software Engineer              | Medium       | CMS integration challenges                                | Blog Feature Implementation                 |
# | 8       | Ensure fast loading times and SEO optimization| 4                     | 1 Software Engineer              | High         | SEO strategies may change based on competition          | Performance and SEO Audit                   |
# | 9       | Integrate social media links                 | 2                     | 1 Software Engineer              | Low          | Social media platform changes may require updates       | Social Media Integration                    |
# | 10      | Create testimonials section                   | 2                     | 1 Designer                       | Low          | Gathering testimonials may take longer than expected    | Completed Testimonials Section              |
# | 11      | Quality Assurance Testing                     | 4                     | 2 QA Engineers                   | High         | Issues found during QA can delay launch                 | QA Testing Report                           |
# | 12      | Review and Final Adjustments                 | 3                     | 1 Software Engineer              | Medium       | Feedback may lead to multiple iterations                | Final Website                              |
# | 13      | Launch Website                               | 1                     | 1 Software Engineer              | Low          | Deployment issues can affect launch                     | Live Website                                |
#
# ---
#
# **3. Summary of Risks and Uncertainties**
#
# 1. **Dependency on Client Feedback**: Several tasks depend on timely feedback from the client, especially design and content-related tasks. Delays in receiving this feedback can lead to project timeline shifts.
#
# 2. **Technical Challenges**: Potential issues integrating features (like the blog or responsive design) with existing systems or cross-device compatibility can arise, which may require additional time for resolution.
#
# 3. **SEO and Performance Optimization**: Strategies that are relevant at the time of implementation may become less effective due to changing algorithms or competing businesses' activities.
#
# 4. **QA Feedback**: The extent and severity of issues discovered during QA testing could necessitate significant revisions, leading to potential shifts in the timeline.
#
# ---
#
# **4. Conclusion**
#
# This estimation report details the time, resources, and effort anticipated for each task in the website project, along with associated risks. A pragmatic approach to scheduling and task execution, combined with proactive risk management, will help ensure that the project meets its objectives and is delivered efficiently within budget.
#
# By maintaining focused communication and regularly revisiting the project plan, we can enhance adaptability to any arising challenges, ensuring the final product is a high-quality website ready for launch by the target date.
#
# ---
#
# This detailed estimation allows us to set clear expectations for the project and provides a framework for effective management and execution.
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for Website Project
#
# | Task ID | Task Description                               | Team Member(s)                 | Start Date | End Date   |
# |---------|------------------------------------------------|--------------------------------|------------|------------|
# | 1       | Create responsive design                       | Bob Smith                      | 01-Nov-23  | 05-Nov-23  |
# | 2       | Implement modern User Interface (UI)          | Jane Doe, Bob Smith            | 06-Nov-23  | 12-Nov-23  |
# | 3       | Develop user-friendly navigation system        | Jane Doe                       | 13-Nov-23  | 15-Nov-23  |
# | 4       | Create "About Us" page                        | Bob Smith                      | 16-Nov-23  | 17-Nov-23  |
# | 5       | Design "Services" page                        | Bob Smith                      | 18-Nov-23  | 20-Nov-23  |
# | 6       | Create "Contact Us" page                      | Bob Smith                      | 21-Nov-23  | 23-Nov-23  |
# | 7       | Implement blog section                         | Jane Doe                       | 24-Nov-23  | 28-Nov-23  |
# | 8       | Ensure fast loading times and SEO optimization | Jane Doe                       | 29-Nov-23  | 02-Dec-23  |
# | 9       | Integrate social media links                  | Jane Doe                       | 03-Dec-23  | 04-Dec-23  |
# | 10      | Create testimonials section                    | Bob Smith                      | 05-Dec-23  | 06-Dec-23  |
# | 11      | Quality Assurance Testing                      | Alice Johnson, Tom Brown       | 07-Dec-23  | 10-Dec-23  |
# | 12      | Review and Final Adjustments                  | Jane Doe                       | 11-Dec-23  | 13-Dec-23  |
# | 13      | Launch Website                                | Jane Doe                       | 14-Dec-23  | 14-Dec-23  |
#
# ### Summary of Rationale Behind Task Allocations
#
# 1. **Bob Smith (Designer)**:
#    - Assigned the initial design tasks such as creating responsive designs, the "About Us", "Services", and "Contact Us" pages. His expertise in design is crucial here, allowing him to create visually appealing and user-friendly interfaces. These tasks have a defined timeline and ripple into subsequent tasks.
#
# 2. **Jane Doe (Software Engineer)**:
#    - Assigned to implement high-level tasks such as the User Interface and blog section as well as ensuring fast loading and SEO optimization. Her technical skill set aligns perfectly with coding and integrating features. By pairing her with Bob Smith during the UI tasks, they can align designs with technical execution collaboratively.
#
# 3. **Alice Johnson & Tom Brown (QA Engineers)**:
#    - Both QA Engineers are tasked with the Quality Assurance Testing phase as this task demands thoroughness. The combined effort will allow the team to identify and address issues efficiently, ensuring a smooth launch for the website.
#
# 4. **Task Scheduling**:
#    - The timeline is strategically laid out to avoid overlaps and ensure that design tasks are completed before the programming tasks begin. For example, design tasks are prioritized early to lay a strong foundation before transitioning to implementation tasks.
#
# 5. **Risk Management**:
#    - The selection of individuals for each task takes into account their current workloads, optimally allowing them to focus on their respective responsibilities without overwhelming any single team member. This way, we mitigate the risks of burnout and maintain project momentum.
#
# This structured approach ensures that tasks are executed efficiently while maximizing the team's potential, establishing clear timelines responsible for delivering a successful final product. The project is set to be launched on 14-Dec-23, keeping in line with the schedule and managing variabilities effectively.

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0029
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         19512          12142               7370                    9

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Create responsive design',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Implement modern User Interface (UI)',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe', 'Bob Smith']},
#   {'task_name': 'Develop user-friendly navigation system',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': "Create 'About Us' page",
#    'estimated_time_hours': 16.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': "Design 'Services' page",
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': "Create 'Contact Us' page",
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Implement blog section',
#    'estimated_time_hours': 32.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Ensure fast loading times and SEO optimization',
#    'estimated_time_hours': 32.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Integrate social media links',
#    'estimated_time_hours': 8.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Create testimonials section',
#    'estimated_time_hours': 8.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Quality Assurance Testing',
#    'estimated_time_hours': 32.0,
#    'required_resources': ['Alice Johnson', 'Tom Brown']},
#   {'task_name': 'Review and Final Adjustments',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Launch Website',
#    'estimated_time_hours': 8.0,
#    'required_resources': ['Jane Doe']}],
#  'milestones': [{'milestone_name': 'Design Completion',
#    'tasks': ['1', '2', '3', '4', '5', '6']},
#   {'milestone_name': 'Functional Completion',
#    'tasks': ['2', '7', '8', '9', '10']},
#   {'milestone_name': 'Testing and Launch', 'tasks': ['11', '12', '13']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
