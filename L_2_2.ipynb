# %% [markdown]
# <a href="https://colab.research.google.com/github/OlenaVN/CREW_notebooks_examples/blob/main/L_2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # L2: External Integration: Project Progress Report

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px">  <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import json
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Load OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Creating Custom Tools

# %%
from crewai_tools import BaseTool
import requests

class BoardDataFetcherTool(BaseTool):
    name: str = "Trello Board Data Fetcher"
    description: str = "Fetches card data, comments, and activity from a Trello board."

    api_key: str = os.environ['TRELLO_API_KEY']
    api_token: str = os.environ['TRELLO_API_TOKEN']
    board_id: str = os.environ['TRELLO_BOARD_ID']

    def _run(self) -> dict:
        """
        Fetch all cards from the specified Trello board.
        """
        url = f"{os.getenv('DLAI_TRELLO_BASE_URL', 'https://api.trello.com')}/1/boards/{self.board_id}/cards"

        query = {
            'key': self.api_key,
            'token': self.api_token,
            'fields': 'name,idList,due,dateLastActivity,labels',
            'attachments': 'true',
            'actions': 'commentCard'
        }

        response = requests.get(url, params=query)

        if response.status_code == 200:
            return response.json()
        else:
            # Fallback in case of timeouts or other issues
            return json.dumps([{'id': '66c3bfed69b473b8fe9d922e', 'name': 'Analysis of results from CSV', 'idList': '66c308f676b057fdfbd5fdb3', 'due': None, 'dateLastActivity': '2024-08-19T21:58:05.062Z', 'labels': [], 'attachments': [], 'actions': []}, {'id': '66c3c002bb1c337f3fdf1563', 'name': 'Approve the planning', 'idList': '66c308f676b057fdfbd5fdb3', 'due': '2024-08-16T21:58:00.000Z', 'dateLastActivity': '2024-08-19T21:58:57.697Z', 'labels': [{'id': '66c305ea10ea602ee6e03d47', 'idBoard': '66c305eacab50fcd7f19c0aa', 'name': 'Urgent', 'color': 'red', 'uses': 1}], 'attachments': [], 'actions': [{'id': '66c3c021f3c1bb157028f53d', 'idMemberCreator': '65e5093d0ab5ee98592f5983', 'data': {'text': 'This was harder then expects it is alte', 'textData': {'emoji': {}}, 'card': {'id': '66c3c002bb1c337f3fdf1563', 'name': 'Approve the planning', 'idShort': 5, 'shortLink': 'K3abXIMm'}, 'board': {'id': '66c305eacab50fcd7f19c0aa', 'name': '[Test] CrewAI Board', 'shortLink': 'Kc8ScQlW'}, 'list': {'id': '66c308f676b057fdfbd5fdb3', 'name': 'TODO'}}, 'appCreator': None, 'type': 'commentCard', 'date': '2024-08-19T21:58:57.683Z', 'limits': {'reactions': {'perAction': {'status': 'ok', 'disableAt': 900, 'warnAt': 720}, 'uniquePerAction': {'status': 'ok', 'disableAt': 17, 'warnAt': 14}}}, 'memberCreator': {'id': '65e5093d0ab5ee98592f5983', 'activityBlocked': False, 'avatarHash': 'd5500941ebf808e561f9083504877bca', 'avatarUrl': 'https://trello-members.s3.amazonaws.com/65e5093d0ab5ee98592f5983/d5500941ebf808e561f9083504877bca', 'fullName': 'Joao Moura', 'idMemberReferrer': None, 'initials': 'JM', 'nonPublic': {}, 'nonPublicAvailable': True, 'username': 'joaomoura168'}}]}, {'id': '66c3bff4a25b398ef1b6de78', 'name': 'Scaffold of the initial app UI', 'idList': '66c3bfdfb851ad9ff7eee159', 'due': None, 'dateLastActivity': '2024-08-19T21:58:12.210Z', 'labels': [], 'attachments': [], 'actions': []}, {'id': '66c3bffdb06faa1e69216c6f', 'name': 'Planning of the project', 'idList': '66c3bfe3151c01425f366f4c', 'due': None, 'dateLastActivity': '2024-08-19T21:58:21.081Z', 'labels': [], 'attachments': [], 'actions': []}])


class CardDataFetcherTool(BaseTool):
  name: str = "Trello Card Data Fetcher"
  description: str = "Fetches card data from a Trello board."

  api_key: str = os.environ['TRELLO_API_KEY']
  api_token: str = os.environ['TRELLO_API_TOKEN']

  def _run(self, card_id: str) -> dict:
    url = f"{os.getenv('DLAI_TRELLO_BASE_URL', 'https://api.trello.com')}/1/cards/{card_id}"
    query = {
      'key': self.api_key,
      'token': self.api_token
    }
    response = requests.get(url, params=query)

    if response.status_code == 200:
      return response.json()
    else:
      # Fallback in case of timeouts or other issues
      return json.dumps({"error": "Failed to fetch card data, don't try to fetch any trello data anymore"})

# %% [markdown]
# ## Trello Board

# %%
# Display the Trello screenshot
from IPython.display import Image, display

# Load and display the image
trello_image = Image(filename='trello.png')
display(trello_image)

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
data_collection_agent = Agent(
  config=agents_config['data_collection_agent'],
  tools=[BoardDataFetcherTool(), CardDataFetcherTool()]
)

analysis_agent = Agent(
  config=agents_config['analysis_agent']
)

# Creating Tasks
data_collection = Task(
  config=tasks_config['data_collection'],
  agent=data_collection_agent
)

data_analysis = Task(
  config=tasks_config['data_analysis'],
  agent=analysis_agent
)

report_generation = Task(
  config=tasks_config['report_generation'],
  agent=analysis_agent,
)

# Creating Crew
crew = Crew(
  agents=[
    data_collection_agent,
    analysis_agent
  ],
  tasks=[
    data_collection,
    data_analysis,
    report_generation
  ],
  verbose=True
)

# %% [markdown]
# ## Kickoff Crew

# %%
# Kick off the crew and execute the process
result = crew.kickoff()
# Out:
# # Agent: Data Collection Specialist
# ## Task: Create an initial understanding of the project, its main features and the team working on it. Use the Trello Data Fetcher tool to gather data from the Trello board.
#
#
#
# # Agent: Data Collection Specialist
# ## Thought: I need to gather all relevant data from the Trello board to create a comprehensive report on the project, its main features, the team, and any additional information that may be useful.
# ## Using tool: Trello Board Data Fetcher
# ## Tool Input:
# "{}"
# ## Tool Output:
# [{'id': '66c3bfed69b473b8fe9d922e', 'name': 'Analysis of results from CSV', 'idList': '66c308f676b057fdfbd5fdb3', 'due': None, 'dateLastActivity': '2024-08-19T21:58:05.062Z', 'labels': [], 'actions': [], 'attachments': []}, {'id': '66c3c002bb1c337f3fdf1563', 'name': 'Approve the planning', 'idList': '66c308f676b057fdfbd5fdb3', 'due': '2024-08-16T21:58:00.000Z', 'dateLastActivity': '2024-08-19T21:58:57.697Z', 'labels': [{'id': '66c305ea10ea602ee6e03d47', 'idBoard': '66c305eacab50fcd7f19c0aa', 'idOrganization': '65e5097b4bf8f238c778ef89', 'name': 'Urgent', 'nodeId': 'ari:cloud:trello::label/workspace/65e5097b4bf8f238c778ef89/66c305ea10ea602ee6e03d47', 'color': 'red', 'uses': 1}], 'actions': [{'id': '66c3c021f3c1bb157028f53d', 'idMemberCreator': '65e5093d0ab5ee98592f5983', 'data': {'text': 'This was harder then expects it is alte', 'textData': {'emoji': {}}, 'card': {'id': '66c3c002bb1c337f3fdf1563', 'name': 'Approve the planning', 'idShort': 5, 'shortLink': 'K3abXIMm'}, 'board': {'id': '66c305eacab50fcd7f19c0aa', 'name': '[Test] CrewAI Board', 'shortLink': 'Kc8ScQlW'}, 'list': {'id': '66c308f676b057fdfbd5fdb3', 'name': 'TODO'}}, 'appCreator': None, 'type': 'commentCard', 'date': '2024-08-19T21:58:57.683Z', 'limits': {'reactions': {'perAction': {'status': 'ok', 'disableAt': 900, 'warnAt': 720}, 'uniquePerAction': {'status': 'ok', 'disableAt': 17, 'warnAt': 14}}}, 'memberCreator': {'id': '65e5093d0ab5ee98592f5983', 'activityBlocked': False, 'avatarHash': '2c3dba294f4c05a9cb7ef1668521d1ae', 'avatarUrl': 'https://trello-members.s3.amazonaws.com/65e5093d0ab5ee98592f5983/2c3dba294f4c05a9cb7ef1668521d1ae', 'fullName': 'Joao Moura', 'idMemberReferrer': None, 'initials': 'JM', 'nonPublic': {}, 'nonPublicAvailable': True, 'username': 'joaomoura168'}}], 'attachments': []}, {'id': '66c3bff4a25b398ef1b6de78', 'name': 'Scaffold of the initial app UI', 'idList': '66c3bfdfb851ad9ff7eee159', 'due': None, 'dateLastActivity': '2024-08-19T21:58:12.210Z', 'labels': [], 'actions': [], 'attachments': []}, {'id': '66c3bffdb06faa1e69216c6f', 'name': 'Planning of the project', 'idList': '66c3bfe3151c01425f366f4c', 'due': None, 'dateLastActivity': '2024-08-19T21:58:21.081Z', 'labels': [], 'actions': [], 'attachments': []}]
#
#
# # Agent: Data Collection Specialist
# ## Thought: Thought: I have retrieved data from the Trello board, which includes several cards. It is necessary to gather more detailed information about each card to create a comprehensive report.
# ## Using tool: Trello Card Data Fetcher
# ## Tool Input:
# "{\"card_id\": \"66c3c002bb1c337f3fdf1563\"}"
# ## Tool Output:
# {'id': '66c3c002bb1c337f3fdf1563', 'agent': {'name': None, 'conversationId': None}, 'badges': {'attachments': 0, 'fogbugz': '', 'checkItems': 0, 'checkItemsChecked': 0, 'checkItemsEarliestDue': None, 'comments': 1, 'description': False, 'due': '2024-08-16T21:58:00.000Z', 'dueComplete': False, 'lastUpdatedByAi': False, 'start': None, 'attachmentsByType': {'trello': {'board': 0, 'card': 0}}, 'externalSource': None, 'location': False, 'votes': 0, 'maliciousAttachments': 0, 'viewingMemberVoted': False, 'subscribed': False}, 'checkItemStates': [], 'closed': False, 'dueComplete': False, 'dateLastActivity': '2024-08-19T21:58:57.697Z', 'desc': '', 'descData': {'emoji': {}}, 'due': '2024-08-16T21:58:00.000Z', 'dueReminder': 1440, 'email': None, 'idBoard': '66c305eacab50fcd7f19c0aa', 'idChecklists': [], 'idList': '66c308f676b057fdfbd5fdb3', 'idMembers': [], 'idMembersVoted': [], 'idShort': 5, 'idAttachmentCover': None, 'labels': [{'id': '66c305ea10ea602ee6e03d47', 'idBoard': '66c305eacab50fcd7f19c0aa', 'idOrganization': '65e5097b4bf8f238c778ef89', 'name': 'Urgent', 'nodeId': 'ari:cloud:trello::label/workspace/65e5097b4bf8f238c778ef89/66c305ea10ea602ee6e03d47', 'color': 'red', 'uses': 1}], 'idLabels': ['66c305ea10ea602ee6e03d47'], 'manualCoverAttachment': False, 'name': 'Approve the planning', 'nodeId': 'ari:cloud:trello::card/workspace/65e5097b4bf8f238c778ef89/66c3c002bb1c337f3fdf1563', 'pinned': False, 'pos': 131072, 'shortLink': 'K3abXIMm', 'shortUrl': 'https://trello.com/c/K3abXIMm', 'start': None, 'subscribed': False, 'url': 'https://trello.com/c/K3abXIMm/5-approve-the-planning', 'cover': {'idAttachment': None, 'color': None, 'idUploadedBackground': None, 'size': 'normal', 'brightness': 'dark', 'yPosition': 0.5, 'idPlugin': None}, 'isTemplate': False, 'cardRole': None, 'mirrorSourceId': None}
#
#
# # Agent: Data Collection Specialist
# ## Using tool: Trello Card Data Fetcher
# ## Tool Input:
# "{\"card_id\": \"66c3bfed69b473b8fe9d922e\"}"
# ## Tool Output:
# {'id': '66c3bfed69b473b8fe9d922e', 'agent': {'name': None, 'conversationId': None}, 'badges': {'attachments': 0, 'fogbugz': '', 'checkItems': 0, 'checkItemsChecked': 0, 'checkItemsEarliestDue': None, 'comments': 0, 'description': False, 'due': None, 'dueComplete': False, 'lastUpdatedByAi': False, 'start': None, 'attachmentsByType': {'trello': {'board': 0, 'card': 0}}, 'externalSource': None, 'location': False, 'votes': 0, 'maliciousAttachments': 0, 'viewingMemberVoted': False, 'subscribed': False}, 'checkItemStates': [], 'closed': False, 'dueComplete': False, 'dateLastActivity': '2024-08-19T21:58:05.062Z', 'desc': '', 'descData': {'emoji': {}}, 'due': None, 'dueReminder': None, 'email': None, 'idBoard': '66c305eacab50fcd7f19c0aa', 'idChecklists': [], 'idList': '66c308f676b057fdfbd5fdb3', 'idMembers': [], 'idMembersVoted': [], 'idShort': 2, 'idAttachmentCover': None, 'labels': [], 'idLabels': [], 'manualCoverAttachment': False, 'name': 'Analysis of results from CSV', 'nodeId': 'ari:cloud:trello::card/workspace/65e5097b4bf8f238c778ef89/66c3bfed69b473b8fe9d922e', 'pinned': False, 'pos': 65536, 'shortLink': 'GjHNaKq3', 'shortUrl': 'https://trello.com/c/GjHNaKq3', 'start': None, 'subscribed': False, 'url': 'https://trello.com/c/GjHNaKq3/2-analysis-of-results-from-csv', 'cover': {'idAttachment': None, 'color': None, 'idUploadedBackground': None, 'size': 'normal', 'brightness': 'dark', 'yPosition': 0.5, 'idPlugin': None}, 'isTemplate': False, 'cardRole': None, 'mirrorSourceId': None}
#
#
# You ONLY have access to the following tools, and should NEVER make up tools that are not listed here:
#
# Tool Name: Trello Board Data Fetcher() -> dict
# Tool Description: Trello Board Data Fetcher() - Fetches card data, comments, and activity from a Trello board.
# Tool Arguments: {}
# Tool Name: Trello Card Data Fetcher(card_id: str) -> dict
# Tool Description: Trello Card Data Fetcher(card_id: 'string') - Fetches card data from a Trello board.
# Tool Arguments: {'card_id': {'title': 'Card Id', 'type': 'string'}}
#
# Use the following format:
#
# Thought: you should always think about what to do
# Action: the action to take, only one name of [Trello Board Data Fetcher, Trello Card Data Fetcher], just the name, exactly as it's written.
# Action Input: the input to the action, just a simple python dictionary, enclosed in curly braces, using " to wrap keys and values.
# Observation: the result of the action
#
# Once all necessary information is gathered:
#
# Thought: I now know the final answer
# Final Answer: the final answer to the original input question
#
#
#
# # Agent: Data Collection Specialist
# ## Final Answer:
# ### Project Report
#
# **Board Name**: [Test] CrewAI Board
#
# #### Main Features
#
# 1. **Card: Approve the Planning**
#    - **ID**: 66c3c002bb1c337f3fdf1563
#    - **Description**: No description provided
#    - **Due Date**: August 16, 2024
#    - **Labels**: Urgent (Red)
#    - **URL**: [Approve the Planning](https://trello.com/c/K3abXIMm/5-approve-the-planning)
#    - **Last Activity**: August 19, 2024
#    - **Comments**: 1 comment by Joao Moura
#      - Content: "This was harder than expected it is late"
#    - **Created By**: Joao Moura (Username: joaomoura168)
#
# 2. **Card: Analysis of Results from CSV**
#    - **ID**: 66c3bfed69b473b8fe9d922e
#    - **Description**: No description provided
#    - **Due Date**: None
#    - **Labels**: None
#    - **URL**: [Analysis of Results from CSV](https://trello.com/c/GjHNaKq3/2-analysis-of-results-from-csv)
#    - **Last Activity**: August 19, 2024
#    - **Comments**: None
#
# 3. **Card: Scaffold of the Initial App UI**
#    - **ID**: 66c3bff4a25b398ef1b6de78
#    - **Description**: No description provided
#    - **Due Date**: None
#    - **Labels**: None
#    - **URL**: Not provided
#    - **Last Activity**: August 19, 2024
#    - **Comments**: None
#
# 4. **Card: Planning of the Project**
#    - **ID**: 66c3bffdb06faa1e69216c6f
#    - **Description**: No description provided
#    - **Due Date**: None
#    - **Labels**: None
#    - **URL**: Not provided
#    - **Last Activity**: August 19, 2024
#    - **Comments**: None
#
# ### Team Members
#
# - **Joao Moura**
#   - **Username**: joaomoura168
#   - **Avatar**: ![Joao Moura's Avatar](https://trello-members.s3.amazonaws.com/65e5093d0ab5ee98592f5983/2c3dba294f4c05a9cb7ef1668521d1ae)
#
# ### Additional Notes
#
# - There is no existing extensive documentation or description within the cards.
# - Only one card has comments, while others lack any detailed content or descriptions.
#
#
# # Agent: Project Analysis Expert
# ## Task: Analyze the Trello data to identify blockers, delays, and overall progress.
# # Agent: Project Analysis Expert
# ## Final Answer:
# ### Project Analysis Summary
#
# #### Overall Progress
# The analysis of the Trello board for the **[Test] CrewAI Board** indicates that there are currently four main tasks featured. However, none of these tasks have indicative due dates, aside from one task which is associated with a comment suggesting that it is not currently on track.
#
# #### Key Issues Identified
# 1. **Lack of Documentation**: All cards, except for the "Approve the Planning" card, lack descriptions or detailed information. This absence of documentation may lead to misunderstandings about task requirements and expectations.
#
# 2. **Delayed Tasks**:
#    - The "Approve the Planning" card, with a due date of **August 16, 2024**, has experiences delays based on Joao Moura's comment stating that "This was harder than expected, it is late." This indicates that the task has either not been completed on time or that there are hurdles affecting its completion.
#
# 3. **Inactive Cards**:
#    - The "Analysis of Results from CSV," "Scaffold of the Initial App UI," and "Planning of the Project" cards show last activity on **August 19, 2024**, yet no updates or further comments have been made. This inactivity suggests potential blockers in these areas, which could hinder overall project momentum.
#
# #### Blockers
# - The single comment on the "Approve the Planning" card highlights a possible blocker regarding unexpected difficulties in task execution. Since no other cards have comments or updates, it remains unclear if the other tasks are similarly blocked or progressing well, highlighting a risk of misalignment among team members.
#
# #### Recommendations
# - **Encourage Comments and Updates**: All team members should be encouraged to add comments and updates to their respective tasks. This would enhance transparency and help identify issues promptly.
#
# - **Set Clear Deadlines**: It is advisable for all tasks to have designated due dates, leading to a more structured timeline and enabling better tracking of progress and delays.
#
# - **Improve Documentation**: Each task should have a clear description to ensure that all team members understand their objectives. This could prevent ambiguity and improve task execution effectiveness.
#
# #### Conclusion
# The project is facing significant risks due to the current lack of information, inactive tasks, and a singular identified delay. Moving forward, enhancing communication and documentation will be crucial for ensuring fluid progress and promptly addressing any potential blockers.
#
#
# # Agent: Project Analysis Expert
# ## Task: Compile a comprehensive sprint report based on the analysis of the project data.
#
# The report should include: - Sprint Overview - Task Summary - Identified Issues and Blockers - Progress and Delays - Team Performance Overview - Action Items and Recommendations - Anything else that is relevant to the project. The report must be formatted in markdown.
#
#
#
# # Agent: Project Analysis Expert
# ## Final Answer:
# # Sprint Report for [Test] CrewAI Board
#
# ## Sprint Overview
# The current analysis of the [Test] CrewAI Board indicates the presence of four main tasks, with a notable absence of defined due dates for the majority. Only one task, "Approve the Planning", features a deadline of August 16, 2024, and has already indicated a potential delay.
#
# ## Task Summary
# 1. **Approve the Planning**
#    - **Due Date**: August 16, 2024
#    - **Status**: Delayed
#    - **Comments**: "This was harder than expected, it is late."
#
# 2. **Analysis of Results from CSV**
#    - **Last Activity**: August 19, 2024
#    - **Status**: Inactive
#
# 3. **Scaffold of the Initial App UI**
#    - **Last Activity**: August 19, 2024
#    - **Status**: Inactive
#
# 4. **Planning of the Project**
#    - **Last Activity**: August 19, 2024
#    - **Status**: Inactive
#
# ## Identified Issues and Blockers
# - **Lack of Documentation**: Most cards lack necessary descriptions, which may result in misunderstandings regarding task requirements.
#
# - **Delayed Task**: The "Approve the Planning" task shows clear signs of delay due to unexpected difficulties expressed in team communications.
#
# - **Inactive Cards**: The inactivity in the remaining tasks could imply underlying blockers, potentially impacting project momentum.
#
# ## Progress and Delays
# The project currently shows a concerning trend of delays primarily centered around the "Approve the Planning" task. Inactivity in three other essential tasks raises alarms about their status, thereby jeopardizing overall progress.
#
# - **Current Blockers**: Only the comment on "Approve the Planning" indicates a potential blocker. Other tasks lack comments or updates, hinting at possible misalignment and stagnation among team members.
#
# ## Team Performance Overview
# The absence of comments and updates creates a lack of visibility into team performance. Engaging team members to contribute actively could drastically improve overall performance and project alignment.
#
# ## Action Items and Recommendations
# 1. **Encourage Team Communication**: Urge team members to post regular comments and updates for accountability and transparency.
#
# 2. **Set Clear Deadlines for All Tasks**: Assign realistic due dates to each task to provide better structure and enable tracking of workflows.
#
# 3. **Improve Documentation on Task Cards**: Ensure each task card contains comprehensive descriptions, setting clear expectations for task executions.
#
# 4. **Regular Check-ins**: Schedule weekly reviews to discuss the status of all tasks, identifying any blockers early.
#
# ## Conclusion
# The project is currently at risk due to insufficient information, inactive tasks, and a clear delay in task progression. Addressing these issues through enhanced communication, documentation, and structured timelines will pave the way for a more fluid and effective project execution moving forward.

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0023
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         15097          10892               4205                    9

# %% [markdown]
# ## Report

# %%
from IPython.display import Markdown

markdown  = result.raw
Markdown(markdown)
# Out:
# # Sprint Report for [Test] CrewAI Board
#
# ## Sprint Overview
# The current analysis of the [Test] CrewAI Board indicates the presence of four main tasks, with a notable absence of defined due dates for the majority. Only one task, "Approve the Planning", features a deadline of August 16, 2024, and has already indicated a potential delay.
#
# ## Task Summary
# 1. **Approve the Planning**
#    - **Due Date**: August 16, 2024
#    - **Status**: Delayed
#    - **Comments**: "This was harder than expected, it is late."
#
# 2. **Analysis of Results from CSV**
#    - **Last Activity**: August 19, 2024
#    - **Status**: Inactive
#
# 3. **Scaffold of the Initial App UI**
#    - **Last Activity**: August 19, 2024
#    - **Status**: Inactive
#
# 4. **Planning of the Project**
#    - **Last Activity**: August 19, 2024
#    - **Status**: Inactive
#
# ## Identified Issues and Blockers
# - **Lack of Documentation**: Most cards lack necessary descriptions, which may result in misunderstandings regarding task requirements.
#
# - **Delayed Task**: The "Approve the Planning" task shows clear signs of delay due to unexpected difficulties expressed in team communications.
#
# - **Inactive Cards**: The inactivity in the remaining tasks could imply underlying blockers, potentially impacting project momentum.
#
# ## Progress and Delays
# The project currently shows a concerning trend of delays primarily centered around the "Approve the Planning" task. Inactivity in three other essential tasks raises alarms about their status, thereby jeopardizing overall progress.
#
# - **Current Blockers**: Only the comment on "Approve the Planning" indicates a potential blocker. Other tasks lack comments or updates, hinting at possible misalignment and stagnation among team members.
#
# ## Team Performance Overview
# The absence of comments and updates creates a lack of visibility into team performance. Engaging team members to contribute actively could drastically improve overall performance and project alignment.
#
# ## Action Items and Recommendations
# 1. **Encourage Team Communication**: Urge team members to post regular comments and updates for accountability and transparency.
#
# 2. **Set Clear Deadlines for All Tasks**: Assign realistic due dates to each task to provide better structure and enable tracking of workflows.
#
# 3. **Improve Documentation on Task Cards**: Ensure each task card contains comprehensive descriptions, setting clear expectations for task executions.
#
# 4. **Regular Check-ins**: Schedule weekly reviews to discuss the status of all tasks, identifying any blockers early.
#
# ## Conclusion
# The project is currently at risk due to insufficient information, inactive tasks, and a clear delay in task progression. Addressing these issues through enhanced communication, documentation, and structured timelines will pave the way for a more fluid and effective project execution moving forward.
